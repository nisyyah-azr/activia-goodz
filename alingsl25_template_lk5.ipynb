# %% [markdown]
# <a href="https://colab.research.google.com/github/nisyyah-azr/activia-goodz/blob/master/alingsl25_template_lk5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <img src="https://drive.usercontent.google.com/download?id=1f1gGVI-rxcHjA90WEGNvvtSXF1pAxQwg&authuser=1" alt="Fasilkom UI" width="300"/>
#
# CSGE602012 • Aljabar Linear
#
# Semester Gasal 2025/2026
#
# Fakultas Ilmu Komputer, Universitas Indonesia
#
# ## **Lembar Kerja 5: *Ruang Hasil Kali Dalam***
#
# ### **Deadline: 17 November 2025, 22.00 WIB**
# </center>
#
# ### **Ketentuan:**
#
# 1. Dokumen template LK dengan format .ipynb telah disediakan di SCeLE
# 2. Jalankan kode pada dokumen .ipynb dan perhatikan dengan saksama apa yang potongan kode tersebut lakukan beserta dengan keluarannya. Jawablah **pertanyaan** yang disisipkan pada potongan program yang diberikan.
# 3. Dokumen Jupyter Notebook yang telah dilengkapi dengan jawaban dikumpulkan dengan format penamaan **[Kelas]_LK5_[NPM]_[NamaLengkap].ipynb** . Contoh: A_LK5_2206081641_TengkuLarasMalahayati.ipynb
# 4. Kumpulkan dokumen tersebut pada submisi yang telah disediakan di SCeLE sebelum **Deadline: [] November 2025, 22.00 WIB**. Keterlambatan pengumpulan akan dikenakan penalti.
# 5. LK ini dirancang sebagai **tugas mandiri**. Plagiarisme tidak diperkenankan dalam bentuk apapun. Adapun kolaborasi berupa diskusi (tanpa menyalin maupun mengambil jawaban orang lain) dan literasi masih diperbolehkan dengan mencantumkan kolaborator dan sumber.

# %% [markdown]
# ## **Pernyataan Integritas**
#
# Wajib diisi. Tanpa pernyataan integritas submisi akan dikenakan penalti.

# %%
# Isi dengan data diri Anda
NAMA = ""
NPM = ""

# Isi dengan NPM teman yang berdiskusi dengan Anda
KOLABORATOR = []

# Isi dengan sumber referensi yang Anda gunakan dalam mengerjakan
REFERENSI = []

# %%
PERNYATAAN_INTEGRITAS = "Saya, %s dengan NPM %s, menyatakan bahwa seluruh jawaban pada pekerjaan ini murni saya kerjakan sendiri.\n\
Saya tidak mencontek jawaban, memberikan jawaban, maupun menyalin dari sumber manapun.\n \
\n\
Jika saya melanggar pernyataan tersebut, saya siap menerima konsekuensi apapun yang diberikan.\n   \
(%s)" % (NAMA, NPM, NAMA)

print(PERNYATAAN_INTEGRITAS)

# %% [markdown]
# # **A. Menentukan Bentuk Orbit Benda langit**

# %% [markdown]
# ***Disclaimer:* Tugas pemrograman kali ini akan sedikit berbeda, karena pertanyaa analisis akan diberikan pada pertengahan pengerjaan kode.**
#
# Fungsi Kepler yang merepresentasikan gerak komet terlihat sebagai berikut:
# $\begin{align} r = \frac{p}{1-e\cos{\theta}} \end{align}$
#
# Bentuk lintasan orbit bergantung terhadap eksentrisitas suatu irisan kerucut (*conic section*) seperti berikut:
# - Jika $e < 1$, persamaan berbentuk elips
# - Jika $e = 1$, persamaan berbentuk parabola
# - Jika $e > 1$, persamaan berbentuk hiperbola
#
# Diberikan data-data sebagai berikut:
# | $\theta$ | $r$ |
# | --- | --- |
# | $\frac{\pi}{4}$ | 45 |
# | $\frac{\pi}{3}$ | 22 |
# | $\frac{2}{3}\pi$ | 6.5 |
# | $\frac{3}{4}\pi$ | 7 |
#
# Tujuan eksperimen ini adalah menentukan apakah gerak orbit suatu benda langit berbentuk elips, parabola, atau hiperbola menggunakan aproksimasi penyelesaian kuadrat terkecil (*Least Square Solution*).

# %% [markdown]
# Sebelum itu, persamaan Kepler perlu dibentuk menjadi sistem persamaan linear $A x = b$. Dengan demikian, jawablah pertanyaan analisis berikut:

# %% [markdown]
# # Pertanyaan Analisis 1

# %% [markdown]
# 1. Konversikan persamaan Kepler dari $\begin{align} r = \frac{p}{1-e\cos{\theta}} \end{align}$ menjadi sistem persamaan linear berbentuk $A x = b$ . Setelah memperoleh solusi $\mathbf{x} = \begin{bmatrix} x_1 \\ x_2 \end{bmatrix}$, jelaskan bagaimana $x_1$ dan $x_2$ berhubungan dengan parameter orbit $p$ dan eksentrisitas $e$.

# %%
import math

theta = [math.pi / 4, math.pi / 3, 2 * math.pi / 3, 3 * math.pi / 4]
r = [45, 22, 6.5, 7]

# TODO: Bentuklah matriks A dan vektor b berikut dengan elemen-elemen yang Anda tentukan pada soal 1
def create_keplerian_matrix(theta, r):
    """Membentuk matriks A dari sudut theta."""
    n = len(theta)
    # TODO

    return A

A = ...
b = ...

display(A)
display(b)

# %% [markdown]
# ... [jawaban pertanyaan analisis nomor 1]

# %% [markdown]
# # Pertanyaan Analisis Nomor 2

# %% [markdown]
# Dalam menyelesaikan permasalahan kuadrat terkecil (*Least Square Problem*/LSP), akan digunakan sistem normal dari SPL $A x = b$.
#
# Sistem normal $A^T A x^  = A^T b$ berbentuk bujur sangkar yang terdiri atas $n$ persamaan dan $n$ *unknown*. Sistem normal pasti bersifat konsisten dan semua penyelesaian persamaan normal merupakan penyelesaian kuadrat terkecil (*Least Square Solutions*/LSS).
#
# Penyelesaian kuadrat terkecil $x_{LSS}$ dari sistem normal akan meminimalkan *Euclidean norm* ($||b - A x||$) pada ruang hasil kali dalam Euclid.

# %% [markdown]
# 2. Jelaskan bagaimana cara kita memastikan bahwa sistem normal $A^T A x^  = A^T b$ memiliki solusi kuadrat terkecil tunggal $x_{LSS}$

# %%
def create_normal_system(A, b):

    n = len(A)

    # TODO
    A_transpose = ...
    A_norm = ...
    b_norm = ...

    return A_norm, b_norm

A_norm, b_norm = create_normal_system(A, b)
display(A_norm)
display(b_norm)

# %% [markdown]
# ... [jawaban pertanyaan analisis nomor 2]

# %% [markdown]
# Selanjutnya, selesaikan sistem normal $A^T A x = A^T b$ menggunakan eliminasi Gauss-Jordan

# %%
# TODO: Implementasikan metode Eliminasi Gauss-Jordan untuk menyelesaikan sistem persamaan linear Ax = b
# Anda dilarang menggunakan fungsi numpy.linalg.solve atau sejenisnya
def naive_gaussian_elimination(A, b):
    # TODO
    return U, bt

def backward_substitution(U, bt)
    # TODO
    return x

x = ...
display(f"Vektor penyelesaian kuadrat terkecil x: {x}")

# %% [markdown]
# # Pertanyaan Analisis Nomor 3

# %% [markdown]
# 3. Dari nilai eksentrisitas $e$ yang diperoleh, tentukan bentuk lintasan komet tersebut berbentuk elips, parabola, atau hiperbola. Berikan penjelasan singkatnya.

# %% [markdown]
# ... [jawaban pertanyaan analisis nomor 3]
